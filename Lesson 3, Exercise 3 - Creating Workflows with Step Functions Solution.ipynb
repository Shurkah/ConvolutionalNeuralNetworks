# %% [markdown]
# ## Exercise: Fill out Preprocess Step

# %%
# %%bash
# pip install stepfunctions
# Out:
# Requirement already satisfied: stepfunctions in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (2.3.0)
# Requirement already satisfied: sagemaker>=2.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from stepfunctions) (2.177.1)
# Requirement already satisfied: boto3>=1.14.38 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from stepfunctions) (1.28.28)
# Requirement already satisfied: pyyaml in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from stepfunctions) (6.0)
# Requirement already satisfied: botocore<1.32.0,>=1.31.28 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3>=1.14.38->stepfunctions) (1.31.28)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3>=1.14.38->stepfunctions) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3>=1.14.38->stepfunctions) (0.6.1)
# Requirement already satisfied: attrs<24,>=23.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker>=2.1.0->stepfunctions) (23.1.0)
# Requirement already satisfied: cloudpickle==2.2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker>=2.1.0->stepfunctions) (2.2.1)
# Requirement already satisfied: google-pasta in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker>=2.1.0->stepfunctions) (0.2.0)
# Requirement already satisfied: numpy<2.0,>=1.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker>=2.1.0->stepfunctions) (1.22.3)
# Requirement already satisfied: protobuf<5.0,>=3.12 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker>=2.1.0->stepfunctions) (4.24.0)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker>=2.1.0->stepfunctions) (1.0.1)
# Requirement already satisfied: importlib-metadata<7.0,>=1.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker>=2.1.0->stepfunctions) (6.8.0)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker>=2.1.0->stepfunctions) (21.3)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker>=2.1.0->stepfunctions) (2.0.3)
# Requirement already satisfied: pathos in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker>=2.1.0->stepfunctions) (0.3.1)
# Requirement already satisfied: schema in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker>=2.1.0->stepfunctions) (0.7.5)
# Requirement already satisfied: jsonschema in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker>=2.1.0->stepfunctions) (4.18.4)
# Requirement already satisfied: platformdirs in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker>=2.1.0->stepfunctions) (3.9.1)
# Requirement already satisfied: tblib==1.7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker>=2.1.0->stepfunctions) (1.7.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore<1.32.0,>=1.31.28->boto3>=1.14.38->stepfunctions) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore<1.32.0,>=1.31.28->boto3>=1.14.38->stepfunctions) (1.26.14)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from importlib-metadata<7.0,>=1.4.0->sagemaker>=2.1.0->stepfunctions) (3.16.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from packaging>=20.0->sagemaker>=2.1.0->stepfunctions) (3.0.9)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from google-pasta->sagemaker>=2.1.0->stepfunctions) (1.16.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonschema->sagemaker>=2.1.0->stepfunctions) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonschema->sagemaker>=2.1.0->stepfunctions) (0.30.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonschema->sagemaker>=2.1.0->stepfunctions) (0.9.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas->sagemaker>=2.1.0->stepfunctions) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas->sagemaker>=2.1.0->stepfunctions) (2023.3)
# Requirement already satisfied: ppft>=1.7.6.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pathos->sagemaker>=2.1.0->stepfunctions) (1.7.6.7)
# Requirement already satisfied: dill>=0.3.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pathos->sagemaker>=2.1.0->stepfunctions) (0.3.7)
# Requirement already satisfied: pox>=0.3.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pathos->sagemaker>=2.1.0->stepfunctions) (0.3.3)
# Requirement already satisfied: multiprocess>=0.70.15 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pathos->sagemaker>=2.1.0->stepfunctions) (0.70.15)
# Requirement already satisfied: contextlib2>=0.5.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from schema->sagemaker>=2.1.0->stepfunctions) (21.6.0)

# %%
from sagemaker import get_execution_role
from sagemaker.sklearn.processing import SKLearnProcessor
from sagemaker.processing import ProcessingInput, ProcessingOutput
from stepfunctions.steps.sagemaker import ProcessingStep
import sagemaker

role = get_execution_role()

PREPROCESSING_JOB_NAME = 'preprocess'
input_data = 's3://vedraugh/Toys_and_Games_5.json.zip'
input_preprocessing_code = 's3://vedraugh/HelloBlazePreprocess.py'
sess = sagemaker.Session()

sklearn_processor = SKLearnProcessor(framework_version='0.20.0',
                                     role=role,
                                     instance_type='ml.m5.large',
                                     instance_count=1)


processed_data_train = "{}{}/{}".format("s3://", sess.default_bucket(), 'hello_blaze_train_scikit')
processed_data_test = "{}{}/{}".format("s3://", sess.default_bucket(), 'hello_blaze_test_scikit')

inputs=[ProcessingInput(source=input_data, destination='/opt/ml/processing/input', input_name = 'input-1'),  ProcessingInput(source=input_preprocessing_code , destination='/opt/ml/processing/input/code', input_name = 'code')]


outputs=[ProcessingOutput(source='/opt/ml/processing/output/train', destination=processed_data_train, output_name = 'train_data'), ProcessingOutput(source='/opt/ml/processing/output/test', destination=processed_data_test, output_name = 'test_data')]


processing_step = ProcessingStep(
    "SageMaker pre-processing step 4",
    processor=sklearn_processor,
    job_name=PREPROCESSING_JOB_NAME,
    inputs=inputs,
    outputs=outputs,
    container_entrypoint=["python3", "/opt/ml/processing/input/code/HelloBlazePreprocess.py"],
)



print(" ".join([processed_data_train, processed_data_test]))
print(inputs)
# Out:
# s3://sagemaker-eu-central-1-961953052480/hello_blaze_train_scikit s3://sagemaker-eu-central-1-961953052480/hello_blaze_test_scikit
# [<sagemaker.processing.ProcessingInput object at 0x7f5e0cf31db0>, <sagemaker.processing.ProcessingInput object at 0x7f5e0cc0ca60>]

# %% [markdown]
# ## Exercise: Fill out Training Step

# %%
from stepfunctions.steps.sagemaker import TrainingStep
import boto3

WORKFLOW_OUTPUT = "s3://vedraugh/udct/workflow_output"
TRAINING_JOB_NAME = "trainingjob"

region_name = boto3.Session().region_name
container = sagemaker.image_uris.retrieve(
    region=region_name, framework="blazingtext", version="latest"
)

helloBlazeEstimator = sagemaker.estimator.Estimator(
    container,
    role=role,
    instance_count=1,
    instance_type='ml.m5.large',
    volume_size=30,
    max_run=360000,
    input_mode="File",
    output_path=WORKFLOW_OUTPUT,
    sagemaker_session=sess,
)

helloBlazeEstimator.set_hyperparameters(mode='supervised')

training_step = TrainingStep(
    "SageMaker Training Step",
    estimator=helloBlazeEstimator,
    data={"train": sagemaker.TrainingInput(processed_data_train, content_type="text/plain"), "validation": sagemaker.TrainingInput(processed_data_test, content_type="text/plain")},
    job_name=TRAINING_JOB_NAME,
    wait_for_completion=True,
)

# %% [markdown]
# ## Exercise: Create & Execute Workflow

# %%
from stepfunctions.steps import Chain
from stepfunctions.workflow import Workflow

workflow_role = 'arn:aws:iam::961953052480:role/stepfunctions_role'

workflow_graph = Chain([processing_step, training_step])
workflow = Workflow(
    name="workflow",
    definition=workflow_graph,
    role=workflow_role,
)

workflow.create()

# Execute workflow
execution = workflow.execute(
    inputs={
        "PreprocessingJobName": PREPROCESSING_JOB_NAME,  # Each pre processing job (SageMaker processing job) requires a unique name,
        "TrainingJobName": TRAINING_JOB_NAME  # Each Sagemaker Training job requires a unique name,       
    }
)

execution_output = execution.get_output(wait=True)

# %%
execution.render_progress()
# Out:
# <link rel="stylesheet" type="text/css" href="https://do0of8uwbahzz.cloudfront.net/graph.css">
# <div id="graph-418" class="workflowgraph">
#
#     <style>
#         .graph-legend ul {
#             list-style-type: none;
#             padding: 10px;
#             padding-left: 0;
#             margin: 0;
#             position: absolute;
#             top: 0;
#             background: transparent;
#         }
#
#         .graph-legend li {
#             margin-left: 10px;
#             display: inline-block;
#         }
#
#         .graph-legend li > div {
#             width: 10px;
#             height: 10px;
#             display: inline-block;
#         }
#
#         .graph-legend .success { background-color: #2BD62E }
#         .graph-legend .failed { background-color: #DE322F }
#         .graph-legend .cancelled { background-color: #DDDDDD }
#         .graph-legend .in-progress { background-color: #53C9ED }
#         .graph-legend .caught-error { background-color: #FFA500 }
#     </style>
#     <div class="graph-legend">
#         <ul>
#             <li>
#                 <div class="success"></div>
#                 <span>Success</span>
#             </li>
#             <li>
#                 <div class="failed"></div>
#                 <span>Failed</span>
#             </li>
#             <li>
#                 <div class="cancelled"></div>
#                 <span>Cancelled</span>
#             </li>
#             <li>
#                 <div class="in-progress"></div>
#                 <span>In Progress</span>
#             </li>
#             <li>
#                 <div class="caught-error"></div>
#                 <span>Caught Error</span>
#             </li>
#         </ul>
#     </div>
#
#     <svg></svg>
#     <a href="https://console.aws.amazon.com/states/home?region=eu-central-1#/executions/details/arn:aws:states:eu-central-1:961953052480:execution:workflow:96017c9a-5774-4109-8d80-1f0bed357839" target="_blank"> Inspect in AWS Step Functions </a>
# </div>
#
# <script type="text/javascript">
#
# require.config({
#     paths: {
#         sfn: "https://do0of8uwbahzz.cloudfront.net/sfn",
#     }
# });
#
# require(['sfn'], function(sfn) {
#     var element = document.getElementById('graph-418')
#
#     var options = {
#         width: parseFloat(getComputedStyle(element, null).width.replace("px", "")),
#         height: 1000,
#         layout: 'LR',
#         resizeHeight: true
#     };
#
#     var definition = {"StartAt": "SageMaker pre-processing step 4", "States": {"SageMaker pre-processing step 4": {"Resource": "arn:aws:states:::sagemaker:createProcessingJob.sync", "Parameters": {"ProcessingJobName": "preprocess", "ProcessingInputs": [{"InputName": "input-1", "AppManaged": false, "S3Input": {"S3Uri": "s3://vedraugh/Toys_and_Games_5.json.zip", "LocalPath": "/opt/ml/processing/input", "S3DataType": "S3Prefix", "S3InputMode": "File", "S3DataDistributionType": "FullyReplicated", "S3CompressionType": "None"}}, {"InputName": "code", "AppManaged": false, "S3Input": {"S3Uri": "s3://vedraugh/HelloBlazePreprocess.py", "LocalPath": "/opt/ml/processing/input/code", "S3DataType": "S3Prefix", "S3InputMode": "File", "S3DataDistributionType": "FullyReplicated", "S3CompressionType": "None"}}], "ProcessingOutputConfig": {"Outputs": [{"OutputName": "train_data", "AppManaged": false, "S3Output": {"S3Uri": "s3://sagemaker-eu-central-1-961953052480/hello_blaze_train_scikit", "LocalPath": "/opt/ml/processing/output/train", "S3UploadMode": "EndOfJob"}}, {"OutputName": "test_data", "AppManaged": false, "S3Output": {"S3Uri": "s3://sagemaker-eu-central-1-961953052480/hello_blaze_test_scikit", "LocalPath": "/opt/ml/processing/output/test", "S3UploadMode": "EndOfJob"}}]}, "AppSpecification": {"ImageUri": "492215442770.dkr.ecr.eu-central-1.amazonaws.com/sagemaker-scikit-learn:0.20.0-cpu-py3", "ContainerEntrypoint": ["python3", "/opt/ml/processing/input/code/HelloBlazePreprocess.py"]}, "RoleArn": "arn:aws:iam::961953052480:role/service-role/AmazonSageMaker-ExecutionRole-20230826T173413", "ProcessingResources": {"ClusterConfig": {"InstanceCount": 1, "InstanceType": "ml.m5.large", "VolumeSizeInGB": 30}}}, "Type": "Task", "Next": "SageMaker Training Step"}, "SageMaker Training Step": {"Resource": "arn:aws:states:::sagemaker:createTrainingJob.sync", "Parameters": {"AlgorithmSpecification": {"TrainingImage": "813361260812.dkr.ecr.eu-central-1.amazonaws.com/blazingtext:1", "TrainingInputMode": "File"}, "OutputDataConfig": {"S3OutputPath": "s3://vedraugh/udct/workflow_output"}, "StoppingCondition": {"MaxRuntimeInSeconds": 360000}, "ResourceConfig": {"VolumeSizeInGB": 30, "InstanceCount": 1, "InstanceType": "ml.m5.large"}, "RoleArn": "arn:aws:iam::961953052480:role/service-role/AmazonSageMaker-ExecutionRole-20230826T173413", "InputDataConfig": [{"DataSource": {"S3DataSource": {"S3DataType": "S3Prefix", "S3Uri": "s3://sagemaker-eu-central-1-961953052480/hello_blaze_train_scikit", "S3DataDistributionType": "FullyReplicated"}}, "ContentType": "text/plain", "ChannelName": "train"}, {"DataSource": {"S3DataSource": {"S3DataType": "S3Prefix", "S3Uri": "s3://sagemaker-eu-central-1-961953052480/hello_blaze_test_scikit", "S3DataDistributionType": "FullyReplicated"}}, "ContentType": "text/plain", "ChannelName": "validation"}], "HyperParameters": {"mode": "supervised"}, "TrainingJobName": "trainingjob", "DebugHookConfig": {"S3OutputPath": "s3://vedraugh/udct/workflow_output"}}, "Type": "Task", "End": true}}};
#     var elementId = '#graph-418';
#     var events = { 'events': [{"timestamp": 1693252216.878, "type": "ExecutionStarted", "id": 1, "previousEventId": 0, "executionStartedEventDetails": {"input": "{\n    \"PreprocessingJobName\": \"preprocess\",\n    \"TrainingJobName\": \"trainingjob\"\n}", "inputDetails": {"truncated": false}, "roleArn": "arn:aws:iam::961953052480:role/stepfunctions_role"}}, {"timestamp": 1693252216.911, "type": "TaskStateEntered", "id": 2, "previousEventId": 0, "stateEnteredEventDetails": {"name": "SageMaker pre-processing step 4", "input": "{\n    \"PreprocessingJobName\": \"preprocess\",\n    \"TrainingJobName\": \"trainingjob\"\n}", "inputDetails": {"truncated": false}}}, {"timestamp": 1693252216.911, "type": "TaskScheduled", "id": 3, "previousEventId": 2, "taskScheduledEventDetails": {"resourceType": "sagemaker", "resource": "createProcessingJob.sync", "region": "eu-central-1", "parameters": "{\"ProcessingJobName\":\"preprocess\",\"ProcessingInputs\":[{\"InputName\":\"input-1\",\"AppManaged\":false,\"S3Input\":{\"S3Uri\":\"s3://vedraugh/reviews_Musical_Instruments_5.json.zip\",\"LocalPath\":\"/opt/ml/processing/input\",\"S3DataType\":\"S3Prefix\",\"S3InputMode\":\"File\",\"S3DataDistributionType\":\"FullyReplicated\",\"S3CompressionType\":\"None\"}},{\"InputName\":\"code\",\"AppManaged\":false,\"S3Input\":{\"S3Uri\":\"s3://vedraugh/HelloBlazePreprocess.py\",\"LocalPath\":\"/opt/ml/processing/input/code\",\"S3DataType\":\"S3Prefix\",\"S3InputMode\":\"File\",\"S3DataDistributionType\":\"FullyReplicated\",\"S3CompressionType\":\"None\"}}],\"ProcessingOutputConfig\":{\"Outputs\":[{\"OutputName\":\"train_data\",\"AppManaged\":false,\"S3Output\":{\"S3Uri\":\"s3://sagemaker-eu-central-1-961953052480/hello_blaze_train_scikit\",\"LocalPath\":\"/opt/ml/processing/output/train\",\"S3UploadMode\":\"EndOfJob\"}},{\"OutputName\":\"test_data\",\"AppManaged\":false,\"S3Output\":{\"S3Uri\":\"s3://sagemaker-eu-central-1-961953052480/hello_blaze_test_scikit\",\"LocalPath\":\"/opt/ml/processing/output/test\",\"S3UploadMode\":\"EndOfJob\"}}]},\"AppSpecification\":{\"ImageUri\":\"492215442770.dkr.ecr.eu-central-1.amazonaws.com/sagemaker-scikit-learn:0.20.0-cpu-py3\",\"ContainerEntrypoint\":[\"python3\",\"/opt/ml/processing/input/code/HelloBlazePreprocess.py\"]},\"RoleArn\":\"arn:aws:iam::961953052480:role/service-role/AmazonSageMaker-ExecutionRole-20230826T173413\",\"ProcessingResources\":{\"ClusterConfig\":{\"InstanceCount\":1,\"InstanceType\":\"ml.m5.large\",\"VolumeSizeInGB\":30}},\"Tags\":[{\"Key\":\"MANAGED_BY_AWS\",\"Value\":\"STARTED_BY_STEP_FUNCTIONS\"}]}"}}, {"timestamp": 1693252216.988, "type": "TaskStarted",
